# %% [markdown]
# **Doug Marcum
# DSC 540 - Term Project Milestone 4**
#
# ### Connecting to an API/Pulling in the Data and Cleaning/Formatting
#
# Perform at least 5 data transformation and/or cleansing steps to your API data. For example: Replace Headers, format data into a more readable format, identify outliers and bad data, find duplicates, fix casing or inconsistent values, conduct Fuzzy Matching.

# %% [markdown]
# ### Load Libraries and Data

# %%
# load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# needed in order to download data from ArcGIS Online using the ArcGIS API for Python
from arcgis.gis import GIS

# %% [markdown]
# Any Item hosted on ArcGIS Online has a unique item ID attribute that can be referenced.

# %%
# Item ID for the Toronto Neighbourhoods Boundary File
public_data_item_id = 'af500b5abb7240399853b35a2362d0c0'

# %% [markdown]
# Since this data is public, credentials are not needed to access it. If it were a private dataset, we would be required to log in with the following:
#
# *gis = GIS(username="username", password="password)*

# %%
# retrieve an item from ArcGIS Online from a known ID value
known_item = GIS().content.get(public_data_item_id)
known_item
# Out:
# <Item title:"Neighbourhood Crime Rates (Boundary File) " type:Feature Layer Collection owner:TorontoPoliceService>

# %% [markdown]
# ### Transform Raw Data into a DataFrame

# %%
# obtain the first feature layer from the item
fl = known_item.layers[0]

# use the `from_layer` static method in the 'spatial' namespace on the Pandas data frame
sdf = pd.DataFrame.spatial.from_layer(fl)

# return the first 5 records. 
sdf.head()
# Out:
#    OBJECTID            Neighbourhood Hood_ID  Population  Assault_2014  \
# 0         1           Yonge-St.Clair     097       12528            20
# 1         2  York University Heights     027       27593           271
# 2         3         Lansing-Westgate     038       16164            44
# 3         4       Yorkdale-Glen Park     031       14804           106
# 4         5      Stonegate-Queensway     016       25051            88
#
#    Assault_2015  Assault_2016  Assault_2017  Assault_2018  Assault_2019  ...  \
# 0            29            39            27            34            37  ...
# 1           296           361           344           357           370  ...
# 2            80            68            85            75            72  ...
# 3           136           174           161           175           209  ...
# 4            71            76            95            87            82  ...
#
#    TheftOver_2016  TheftOver_2017  TheftOver_2018  TheftOver_2019  \
# 0               8               0               3               6
# 1              37              39              38              28
# 2               5              11               6              11
# 3              26              23              20              29
# 4               4               6               7               4
#
#    TheftOver_AVG  TheftOver_CHG  TheftOver_Rate_2019   Shape__Area  \
# 0            4.3           1.00                 47.9  1.161315e+06
# 1           36.3          -0.26                101.5  1.324666e+07
# 2            7.0           0.83                 68.1  5.346186e+06
# 3           22.5           0.45                195.9  6.038326e+06
# 4            6.0          -0.43                 16.0  7.946202e+06
#
#    Shape__Length                                              SHAPE
# 0    5873.270582  {"rings": [[[629662.070348966, 4837487.4889266...
# 1   18504.777326  {"rings": [[[620308.016744937, 4846066.4574399...
# 2   11112.109625  {"rings": [[[625561.290588443, 4846350.4188880...
# 3   10079.426920  {"rings": [[[625702.12287765, 4840137.07697177...
# 4   11853.189878  {"rings": [[[621554.454563301, 4833597.3633473...
#
# [5 rows x 61 columns]

# %%
# quick look at the info of the data
sdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140 entries, 0 to 139
# Data columns (total 61 columns):
# OBJECTID                   140 non-null int64
# Neighbourhood              140 non-null object
# Hood_ID                    140 non-null object
# Population                 140 non-null int64
# Assault_2014               140 non-null int64
# Assault_2015               140 non-null int64
# Assault_2016               140 non-null int64
# Assault_2017               140 non-null int64
# Assault_2018               140 non-null int64
# Assault_2019               140 non-null int64
# Assault_AVG                140 non-null float64
# Assault_CHG                140 non-null float64
# Assault_Rate_2019          140 non-null float64
# AutoTheft_2014             140 non-null int64
# AutoTheft_2015             140 non-null int64
# AutoTheft_2016             140 non-null int64
# AutoTheft_2017             140 non-null int64
# AutoTheft_2018             140 non-null int64
# AutoTheft_2019             140 non-null int64
# AutoTheft_AVG              140 non-null float64
# AutoTheft_CHG              140 non-null float64
# AutoTheft_Rate_2019        140 non-null float64
# BreakandEnter_2014         140 non-null int64
# BreakandEnter_2015         140 non-null int64
# BreakandEnter_2016         140 non-null int64
# BreakandEnter_2017         140 non-null int64
# BreakandEnter_2018         140 non-null int64
# BreakandEnter_2019         140 non-null int64
# BreakandEnter_AVG          140 non-null float64
# BreakandEnter_CHG          140 non-null float64
# BreakandEnter_Rate_2019    140 non-null float64
# Homicide_2014              140 non-null int64
# Homicide_2015              140 non-null int64
# Homicide_2016              140 non-null int64
# Homicide_2017              140 non-null int64
# Homicide_2018              140 non-null int64
# Homicide_2019              140 non-null int64
# Homicide_AVG               140 non-null float64
# Homicide_CHG               140 non-null float64
# Homicide_Rate_2019         140 non-null float64
# Robbery_2014               140 non-null int64
# Robbery_2015               140 non-null int64
# Robbery_2016               140 non-null int64
# Robbery_2017               140 non-null int64
# Robbery_2018               140 non-null int64
# Robbery_2019               140 non-null int64
# Robbery_AVG                140 non-null float64
# Robbery_CHG                140 non-null float64
# Robbery_Rate_2019          140 non-null float64
# TheftOver_2014             140 non-null int64
# TheftOver_2015             140 non-null int64
# TheftOver_2016             140 non-null int64
# TheftOver_2017             140 non-null int64
# TheftOver_2018             140 non-null int64
# TheftOver_2019             140 non-null int64
# TheftOver_AVG              140 non-null float64
# TheftOver_CHG              140 non-null float64
# TheftOver_Rate_2019        140 non-null float64
# Shape__Area                140 non-null float64
# Shape__Length              140 non-null float64
# SHAPE                      140 non-null geometry
# dtypes: float64(20), geometry(1), int64(38), object(2)
# memory usage: 66.8+ KB

# %% [markdown]
# ### Remove Unnecessary Initial Columns
#
# With approximately half of the columns not needed for this analysis, they will be dropped. Once joined with the other data frames, new columns will be created.

# %%
# columns before
print('Number of columns before columns dropped:', sdf.shape[1])
# Out:
# Number of columns before columns dropped: 61

# %%
# dropping of columns
sdf.drop(sdf.columns[sdf.columns.str.contains('2014')], axis = 1, inplace = True)
sdf.drop(sdf.columns[sdf.columns.str.contains('2015')], axis = 1, inplace = True)
sdf.drop(sdf.columns[sdf.columns.str.contains('AVG')], axis = 1, inplace = True)
sdf.drop(sdf.columns[sdf.columns.str.contains('CHG')], axis = 1, inplace = True)
sdf.drop(sdf.columns[sdf.columns.str.contains('Rate')], axis = 1, inplace = True)
sdf.drop(sdf.columns[sdf.columns.str.contains('ID')], axis = 1, inplace = True)
sdf = sdf.drop(columns=['Shape__Area', 'Shape__Length', 'SHAPE'])

# %%
# columns after
print('Number of columns after columns dropped:', sdf.shape[1])
# Out:
# Number of columns after columns dropped: 26

# %% [markdown]
# ### Modify Header
#
# Even though this is not the final header, in order to have a clean standardized process until then, the folllowing steps are completed.

# %%
# standardize column names to lowercase
sdf.columns = map(str.lower, sdf.columns)

# %%
# 'neighbourhood' changed to 'neighborhood' to avoid possible future typos
# 'population' changed to 'population_2019', to not be confused with other populations from the 2016 data sets
sdf.rename(columns={'neighbourhood': 'neighborhood', 'population': 'population_2019'}, inplace = True)

# %%
# quick look at the data
sdf.head()
# Out:
#               neighborhood  population_2019  assault_2016  assault_2017  \
# 0           Yonge-St.Clair            12528            39            27
# 1  York University Heights            27593           361           344
# 2         Lansing-Westgate            16164            68            85
# 3       Yorkdale-Glen Park            14804           174           161
# 4      Stonegate-Queensway            25051            76            95
#
#    assault_2018  assault_2019  autotheft_2016  autotheft_2017  autotheft_2018  \
# 0            34            37               7               2               6
# 1           357           370             105              92              92
# 2            75            72              27              26              16
# 3           175           209              41              52              63
# 4            87            82              12              32              31
#
#    autotheft_2019  ...  homicide_2018  homicide_2019  robbery_2016  \
# 0               6  ...              0              0             6
# 1             144  ...              1              0            70
# 2              32  ...             10              0             9
# 3              61  ...              2              1            24
# 4              34  ...              0              0            16
#
#    robbery_2017  robbery_2018  robbery_2019  theftover_2016  theftover_2017  \
# 0             8             5             4               8               0
# 1            75            88            79              37              39
# 2            17            35            11               5              11
# 3            35            44            42              26              23
# 4            26            25            22               4               6
#
#    theftover_2018  theftover_2019
# 0               3               6
# 1              38              28
# 2               6              11
# 3              20              29
# 4               7               4
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Check For Missing Values

# %%
# quick function to look for missing values in each column
def miss_values(df):
    for c in df.columns:
        miss = df[c].isnull().sum() 
        if miss > 0: 
            print(f'Missing value(s) for {c}: {miss}') 
        else: 
            print(f'0 missing values for {c}')

# check if any columns are null
miss_values(sdf)
# Out:
# 0 missing values for neighborhood
# 0 missing values for population_2019
# 0 missing values for assault_2016
# 0 missing values for assault_2017
# 0 missing values for assault_2018
# 0 missing values for assault_2019
# 0 missing values for autotheft_2016
# 0 missing values for autotheft_2017
# 0 missing values for autotheft_2018
# 0 missing values for autotheft_2019
# 0 missing values for breakandenter_2016
# 0 missing values for breakandenter_2017
# 0 missing values for breakandenter_2018
# 0 missing values for breakandenter_2019
# 0 missing values for homicide_2016
# 0 missing values for homicide_2017
# 0 missing values for homicide_2018
# 0 missing values for homicide_2019
# 0 missing values for robbery_2016
# 0 missing values for robbery_2017
# 0 missing values for robbery_2018
# 0 missing values for robbery_2019
# 0 missing values for theftover_2016
# 0 missing values for theftover_2017
# 0 missing values for theftover_2018
# 0 missing values for theftover_2019

# %% [markdown]
# ### Check For Duplicates
#
# Knowing that there may be duplicate numbers of incidents from neighborhood to neighborhood, it is still important to make certain there are no duplicate neighborhoods listed.

# %%
# look for duplicate neighborhoods being listed
print('Duplicate neighborhoods found:', sdf.neighborhood.duplicated().any())
# Out:
# Duplicate neighborhoods found: False

# %% [markdown]
# ### Outliers
#
# Here we plot a number of histograms to look for outliers. Outliers here are not analomalies per se, but rather areas of lower and higher occurrences of crime. This spread is not uncommon in major, metropolitan cities (most areas with lower crime rates, with a small number of areas with excessively higher crime rates). These factors will play a larger role in the next milestone.

# %%
# set up the figure size
plt.rcParams['figure.figsize'] = (20, 25)

# make subplots
fig, axes = plt.subplots(nrows = 3, ncols = 2)

# create label
label = ['2016', '2017', '2018', '2019']

# create histograms for observed crimes
axes[0, 0].hist([sdf.assault_2016, sdf.assault_2017, sdf.assault_2018, sdf.assault_2019], bins = 'auto')
axes[0, 0].set_title('Assualts By Year', fontsize=20)
axes[0, 0].set_xlabel('Number of Assualts', fontsize=20)
axes[0, 0].set_ylabel('Counts', fontsize=20)
axes[0, 0].legend(label)

axes[0, 1].hist([sdf.autotheft_2016, sdf.autotheft_2017, sdf.autotheft_2018, sdf.autotheft_2019], bins = 'auto')
axes[0, 1].set_title('Auto Thefts By Year', fontsize=20)
axes[0, 1].set_xlabel('Number of Auto Thefts', fontsize=20)
axes[0, 1].set_ylabel('Counts', fontsize=20)
axes[0, 1].legend(label)

axes[1, 0].hist([sdf.breakandenter_2016, sdf.breakandenter_2017, sdf.breakandenter_2018, sdf.breakandenter_2019], bins = 'auto')
axes[1, 0].set_title('Breaking and Enterings By Year', fontsize=20)
axes[1, 0].set_xlabel('Number of Breaking and Enterings', fontsize=20)
axes[1, 0].set_ylabel('Counts', fontsize=20)
axes[1, 0].legend(label)

axes[1, 1].hist([sdf.homicide_2016, sdf.homicide_2017, sdf.homicide_2018, sdf.homicide_2019], bins = 'auto')
axes[1, 1].set_title('Homicides By Year', fontsize=20)
axes[1, 1].set_xlabel('Number of Homicides', fontsize=20)
axes[1, 1].set_ylabel('Counts', fontsize=20)
axes[1, 1].legend(label)

axes[2, 0].hist([sdf.robbery_2016, sdf.robbery_2017, sdf.robbery_2018, sdf.robbery_2019], bins = 'auto')
axes[2, 0].set_title('Robberies By Year', fontsize=20)
axes[2, 0].set_xlabel('Number of Robberies', fontsize=20)
axes[2, 0].set_ylabel('Counts', fontsize=20)
axes[2, 0].legend(label)

axes[2, 1].hist([sdf.theftover_2016, sdf.theftover_2017, sdf.theftover_2018, sdf.theftover_2019], bins = 'auto')
axes[2, 1].set_title('Thefts Over $5000 By Year', fontsize=20)
axes[2, 1].set_xlabel('Number of Thefts Over $5000', fontsize=20)
axes[2, 1].set_ylabel('Counts', fontsize=20)
axes[2, 1].legend(label)
plt.show()

# %% [markdown]
# ### Transpose

# %%
# since we will be transposing on 'neighborhood', first let us sort the column, making it easier to read alphabetically
sdf.sort_values(by = ['neighborhood'], inplace = True)
sdf.head()
# Out:
#                     neighborhood  population_2019  assault_2016  assault_2017  \
# 79               Agincourt North            29113            77            71
# 80  Agincourt South-Malvern West            23757           136           115
# 86                     Alderwood            12054            39            21
# 56                         Annex            30526           257           248
# 84             Banbury-Don Mills            27695            84           109
#
#     assault_2018  assault_2019  autotheft_2016  autotheft_2017  \
# 79            79            79              16              32
# 80           114           123              26              35
# 86            30            36              17              14
# 56           246           288              19              23
# 84            77            74               7              16
#
#     autotheft_2018  autotheft_2019  ...  homicide_2018  homicide_2019  \
# 79              42              42  ...              0              0
# 80              36              62  ...              1              0
# 86              25              14  ...              0              0
# 56              33              30  ...              2              1
# 84              27              42  ...              0              0
#
#     robbery_2016  robbery_2017  robbery_2018  robbery_2019  theftover_2016  \
# 79            13            22            42            35               5
# 80            21            34            33            29              11
# 86            11             6             8             5              10
# 56            34            64            42            31              22
# 84            21            10             7            10              11
#
#     theftover_2017  theftover_2018  theftover_2019
# 79              11               4               2
# 80              14              10              15
# 86               7               7               7
# 56              29              45              42
# 84               5               8              14
#
# [5 rows x 26 columns]

# %%
# transpose the data frame and make 'neighborhood' the header
crime = sdf.T
crime.columns = crime.iloc[0]
crime = crime.drop(crime.index[0])
print('Shape:', crime.shape)
crime.head()
# Out:
# Shape: (25, 140)
# neighborhood    Agincourt North Agincourt South-Malvern West Alderwood  Annex  \
# population_2019           29113                        23757     12054  30526
# assault_2016                 77                          136        39    257
# assault_2017                 71                          115        21    248
# assault_2018                 79                          114        30    246
# assault_2019                 79                          123        36    288
#
# neighborhood    Banbury-Don Mills Bathurst Manor Bay Street Corridor  \
# population_2019             27695          15873               25797
# assault_2016                   84             64                 727
# assault_2017                  109             51                 852
# assault_2018                   77             58                 808
# assault_2019                   74             50                 916
#
# neighborhood    Bayview Village Bayview Woods-Steeles Bedford Park-Nortown  \
# population_2019           21396                 13154                23236
# assault_2016                 84                    35                   36
# assault_2017                 67                    33                   48
# assault_2018                 60                    49                   42
# assault_2019                 66                    45                   62
#
# neighborhood     ... Willowdale West Willowridge-Martingrove-Richview Woburn  \
# population_2019  ...           16936                            22156  53485
# assault_2016     ...              97                              102    365
# assault_2017     ...              92                              103    400
# assault_2018     ...             107                               78    369
# assault_2019     ...             112                              101    427
#
# neighborhood    Woodbine Corridor Woodbine-Lumsden Wychwood Yonge-Eglinton  \
# population_2019             12541             7865    14349          11817
# assault_2016                   79               33       86             73
# assault_2017                   75               32       55             73
# assault_2018                  101               37       76             78
# assault_2019                   98               30       74            103
#
# neighborhood    Yonge-St.Clair York University Heights Yorkdale-Glen Park
# population_2019          12528                   27593              14804
# assault_2016                39                     361                174
# assault_2017                27                     344                161
# assault_2018                34                     357                175
# assault_2019                37                     370                209
#
# [5 rows x 140 columns]

# %% [markdown]
# ### Modify New Header

# %%
# cleaning of the header to standardize and replace ' ' and '.' with '_'
crime.columns = [x.lower() for x in crime.columns]
crime.columns = [x.replace('.', '_') for x in crime.columns]
crime.columns = [x.replace(' ', '_') for x in crime.columns]
print(crime.columns.values)
# Out:
# ['agincourt_north' 'agincourt_south-malvern_west' 'alderwood' 'annex'
#  'banbury-don_mills' 'bathurst_manor' 'bay_street_corridor'
#  'bayview_village' 'bayview_woods-steeles' 'bedford_park-nortown'
#  'beechborough-greenbrook' 'bendale' 'birchcliffe-cliffside' 'black_creek'
#  'blake-jones' 'briar_hill-belgravia' 'bridle_path-sunnybrook-york_mills'
#  'broadview_north' 'brookhaven-amesbury' 'cabbagetown-south_st_james_town'
#  'caledonia-fairbank' 'casa_loma' 'centennial_scarborough'
#  'church-yonge_corridor' 'clairlea-birchmount' 'clanton_park' 'cliffcrest'
#  'corso_italia-davenport' 'danforth' 'danforth_east_york'
#  'don_valley_village' 'dorset_park' 'dovercourt-wallace_emerson-junction'
#  'downsview-roding-cfb' 'dufferin_grove' 'east_end-danforth'
#  'edenbridge-humber_valley' 'eglinton_east' 'elms-old_rexdale'
#  'englemount-lawrence' 'eringate-centennial-west_deane'
#  'etobicoke_west_mall' 'flemingdon_park' 'forest_hill_north'
#  'forest_hill_south' 'glenfield-jane_heights' 'greenwood-coxwell'
#  'guildwood' 'henry_farm' 'high_park_north' 'high_park-swansea'
#  'highland_creek' 'hillcrest_village' 'humber_heights-westmount'
#  'humber_summit' 'humbermede' 'humewood-cedarvale' 'ionview'
#  'islington-city_centre_west' 'junction_area' 'keelesdale-eglinton_west'
#  'kennedy_park' 'kensington-chinatown' 'kingsview_village-the_westway'
#  'kingsway_south' "l'amoreaux" 'lambton_baby_point' 'lansing-westgate'
#  'lawrence_park_north' 'lawrence_park_south' 'leaside-bennington'
#  'little_portugal' 'long_branch' 'malvern' 'maple_leaf' 'markland_wood'
#  'milliken' 'mimico' 'morningside' 'moss_park' 'mount_dennis'
#  'mount_olive-silverstone-jamestown' 'mount_pleasant_east'
#  'mount_pleasant_west' 'new_toronto' 'newtonbrook_east' 'newtonbrook_west'
#  'niagara' 'north_riverdale' 'north_st_james_town' "o'connor-parkview"
#  'oakridge' 'oakwood_village' 'old_east_york' 'palmerston-little_italy'
#  'parkwoods-donalda' 'pelmo_park-humberlea' 'playter_estates-danforth'
#  'pleasant_view' 'princess-rosethorn' 'regent_park' 'rexdale-kipling'
#  'rockcliffe-smythe' 'roncesvalles' 'rosedale-moore_park' 'rouge'
#  'runnymede-bloor_west_village' 'rustic' 'scarborough_village'
#  'south_parkdale' 'south_riverdale' 'st_andrew-windfields' 'steeles'
#  'stonegate-queensway' "tam_o'shanter-sullivan" 'taylor-massey'
#  'the_beaches' 'thistletown-beaumond_heights' 'thorncliffe_park'
#  'trinity-bellwoods' 'university' 'victoria_village'
#  'waterfront_communities-the_island' 'west_hill' 'west_humber-clairville'
#  'westminster-branson' 'weston' 'weston-pellam_park' 'wexford/maryvale'
#  'willowdale_east' 'willowdale_west' 'willowridge-martingrove-richview'
#  'woburn' 'woodbine_corridor' 'woodbine-lumsden' 'wychwood'
#  'yonge-eglinton' 'yonge-st_clair' 'york_university_heights'
#  'yorkdale-glen_park']

# %%
# after looking at the column names, there are still an error to correct
# 'weston-pellam_park' should be 'weston-pelham_park' 
crime = crime.rename(columns = {'weston-pellam_park': 'weston-pelham_park'})

# %% [markdown]
# ### Add Necessary Columns

# %%
# reset index, rename index column topic
crime = crime.reset_index()
crime.rename(columns={'index': 'characteristic'}, inplace=True)
crime.head()
# Out:
#     characteristic agincourt_north agincourt_south-malvern_west alderwood  \
# 0  population_2019           29113                        23757     12054
# 1     assault_2016              77                          136        39
# 2     assault_2017              71                          115        21
# 3     assault_2018              79                          114        30
# 4     assault_2019              79                          123        36
#
#    annex banbury-don_mills bathurst_manor bay_street_corridor bayview_village  \
# 0  30526             27695          15873               25797           21396
# 1    257                84             64                 727              84
# 2    248               109             51                 852              67
# 3    246                77             58                 808              60
# 4    288                74             50                 916              66
#
#   bayview_woods-steeles  ... willowdale_west willowridge-martingrove-richview  \
# 0                 13154  ...           16936                            22156
# 1                    35  ...              97                              102
# 2                    33  ...              92                              103
# 3                    49  ...             107                               78
# 4                    45  ...             112                              101
#
#   woburn woodbine_corridor woodbine-lumsden wychwood yonge-eglinton  \
# 0  53485             12541             7865    14349          11817
# 1    365                79               33       86             73
# 2    400                75               32       55             73
# 3    369               101               37       76             78
# 4    427                98               30       74            103
#
#   yonge-st_clair york_university_heights yorkdale-glen_park
# 0          12528                   27593              14804
# 1             39                     361                174
# 2             27                     344                161
# 3             34                     357                175
# 4             37                     370                209
#
# [5 rows x 141 columns]

# %%
# create a blank series 
cat_new = pd.Series([]) 
  
# run a for loop and assign values to series 
for i in range(len(crime)): 
    if crime['characteristic'][i] == 'population_2019': 
        cat_new[i]= 'Population'
    else: 
        cat_new[i]= 'Crime'
        
# insert new column with values of list made above         
crime.insert(0, 'category', cat_new) 

crime.head()
# Out:
#      category   characteristic agincourt_north agincourt_south-malvern_west  \
# 0  Population  population_2019           29113                        23757
# 1       Crime     assault_2016              77                          136
# 2       Crime     assault_2017              71                          115
# 3       Crime     assault_2018              79                          114
# 4       Crime     assault_2019              79                          123
#
#   alderwood  annex banbury-don_mills bathurst_manor bay_street_corridor  \
# 0     12054  30526             27695          15873               25797
# 1        39    257                84             64                 727
# 2        21    248               109             51                 852
# 3        30    246                77             58                 808
# 4        36    288                74             50                 916
#
#   bayview_village  ... willowdale_west willowridge-martingrove-richview  \
# 0           21396  ...           16936                            22156
# 1              84  ...              97                              102
# 2              67  ...              92                              103
# 3              60  ...             107                               78
# 4              66  ...             112                              101
#
#   woburn woodbine_corridor woodbine-lumsden wychwood yonge-eglinton  \
# 0  53485             12541             7865    14349          11817
# 1    365                79               33       86             73
# 2    400                75               32       55             73
# 3    369               101               37       76             78
# 4    427                98               30       74            103
#
#   yonge-st_clair york_university_heights yorkdale-glen_park
# 0          12528                   27593              14804
# 1             39                     361                174
# 2             27                     344                161
# 3             34                     357                175
# 4             37                     370                209
#
# [5 rows x 142 columns]

# %%
# create a blank series
topic_new = pd.Series([]) 
  
# run a for loop and assign values to series 
for i in range(len(crime)): 
    if crime['category'][i] == 'Population': 
        topic_new[i]= 'Population and dwellings'
    else: 
        topic_new[i]= 'Crimes by year'
        
# insert new column with values of list made above         
crime.insert(1, "topic", topic_new) 

crime.head()
# Out:
#      category                     topic   characteristic agincourt_north  \
# 0  Population  Population and dwellings  population_2019           29113
# 1       Crime            Crimes by year     assault_2016              77
# 2       Crime            Crimes by year     assault_2017              71
# 3       Crime            Crimes by year     assault_2018              79
# 4       Crime            Crimes by year     assault_2019              79
#
#   agincourt_south-malvern_west alderwood  annex banbury-don_mills  \
# 0                        23757     12054  30526             27695
# 1                          136        39    257                84
# 2                          115        21    248               109
# 3                          114        30    246                77
# 4                          123        36    288                74
#
#   bathurst_manor bay_street_corridor  ... willowdale_west  \
# 0          15873               25797  ...           16936
# 1             64                 727  ...              97
# 2             51                 852  ...              92
# 3             58                 808  ...             107
# 4             50                 916  ...             112
#
#   willowridge-martingrove-richview woburn woodbine_corridor woodbine-lumsden  \
# 0                            22156  53485             12541             7865
# 1                              102    365                79               33
# 2                              103    400                75               32
# 3                               78    369               101               37
# 4                              101    427                98               30
#
#   wychwood yonge-eglinton yonge-st_clair york_university_heights  \
# 0    14349          11817          12528                   27593
# 1       86             73             39                     361
# 2       55             73             27                     344
# 3       76             78             34                     357
# 4       74            103             37                     370
#
#   yorkdale-glen_park
# 0              14804
# 1                174
# 2                161
# 3                175
# 4                209
#
# [5 rows x 143 columns]

# %%
# create column with sums for total of city of toronto
crime['city_of_toronto']= crime.iloc[:, -140:].sum(axis=1)

# create col_name by popping city_of_toronto
col_name = crime.pop('city_of_toronto')

# insert col_name into crime 4th column location
crime.insert(3, 'city_of_toronto', col_name)

# convert column to integers
crime['city_of_toronto'] = crime['city_of_toronto'].astype(int)

crime.head()
# Out:
#      category                     topic   characteristic  city_of_toronto  \
# 0  Population  Population and dwellings  population_2019          2731571
# 1       Crime            Crimes by year     assault_2016            18508
# 2       Crime            Crimes by year     assault_2017            18845
# 3       Crime            Crimes by year     assault_2018            19451
# 4       Crime            Crimes by year     assault_2019            20426
#
#   agincourt_north agincourt_south-malvern_west alderwood  annex  \
# 0           29113                        23757     12054  30526
# 1              77                          136        39    257
# 2              71                          115        21    248
# 3              79                          114        30    246
# 4              79                          123        36    288
#
#   banbury-don_mills bathurst_manor  ... willowdale_west  \
# 0             27695          15873  ...           16936
# 1                84             64  ...              97
# 2               109             51  ...              92
# 3                77             58  ...             107
# 4                74             50  ...             112
#
#   willowridge-martingrove-richview woburn woodbine_corridor woodbine-lumsden  \
# 0                            22156  53485             12541             7865
# 1                              102    365                79               33
# 2                              103    400                75               32
# 3                               78    369               101               37
# 4                              101    427                98               30
#
#   wychwood yonge-eglinton yonge-st_clair york_university_heights  \
# 0    14349          11817          12528                   27593
# 1       86             73             39                     361
# 2       55             73             27                     344
# 3       76             78             34                     357
# 4       74            103             37                     370
#
#   yorkdale-glen_park
# 0              14804
# 1                174
# 2                161
# 3                175
# 4                209
#
# [5 rows x 144 columns]

# %% [markdown]
# ### Final Missing Values Check

# %%
# check if any columns are missing values
miss_values(crime)
# Out:
# 0 missing values for category
# 0 missing values for topic
# 0 missing values for characteristic
# 0 missing values for city_of_toronto
# 0 missing values for agincourt_north
# 0 missing values for agincourt_south-malvern_west
# 0 missing values for alderwood
# 0 missing values for annex
# 0 missing values for banbury-don_mills
# 0 missing values for bathurst_manor
# 0 missing values for bay_street_corridor
# 0 missing values for bayview_village
# 0 missing values for bayview_woods-steeles
# 0 missing values for bedford_park-nortown
# 0 missing values for beechborough-greenbrook
# 0 missing values for bendale
# 0 missing values for birchcliffe-cliffside
# 0 missing values for black_creek
# 0 missing values for blake-jones
# 0 missing values for briar_hill-belgravia
# 0 missing values for bridle_path-sunnybrook-york_mills
# 0 missing values for broadview_north
# 0 missing values for brookhaven-amesbury
# 0 missing values for cabbagetown-south_st_james_town
# 0 missing values for caledonia-fairbank
# 0 missing values for casa_loma
# 0 missing values for centennial_scarborough
# 0 missing values for church-yonge_corridor
# 0 missing values for clairlea-birchmount
# 0 missing values for clanton_park
# 0 missing values for cliffcrest
# 0 missing values for corso_italia-davenport
# 0 missing values for danforth
# 0 missing values for danforth_east_york
# 0 missing values for don_valley_village
# 0 missing values for dorset_park
# 0 missing values for dovercourt-wallace_emerson-junction
# 0 missing values for downsview-roding-cfb
# 0 missing values for dufferin_grove
# 0 missing values for east_end-danforth
# 0 missing values for edenbridge-humber_valley
# 0 missing values for eglinton_east
# 0 missing values for elms-old_rexdale
# 0 missing values for englemount-lawrence
# 0 missing values for eringate-centennial-west_deane
# 0 missing values for etobicoke_west_mall
# 0 missing values for flemingdon_park
# 0 missing values for forest_hill_north
# 0 missing values for forest_hill_south
# 0 missing values for glenfield-jane_heights
# 0 missing values for greenwood-coxwell
# 0 missing values for guildwood
# 0 missing values for henry_farm
# 0 missing values for high_park_north
# 0 missing values for high_park-swansea
# 0 missing values for highland_creek
# 0 missing values for hillcrest_village
# 0 missing values for humber_heights-westmount
# 0 missing values for humber_summit
# 0 missing values for humbermede
# 0 missing values for humewood-cedarvale
# 0 missing values for ionview
# 0 missing values for islington-city_centre_west
# 0 missing values for junction_area
# 0 missing values for keelesdale-eglinton_west
# 0 missing values for kennedy_park
# 0 missing values for kensington-chinatown
# 0 missing values for kingsview_village-the_westway
# 0 missing values for kingsway_south
# 0 missing values for l'amoreaux
# 0 missing values for lambton_baby_point
# 0 missing values for lansing-westgate
# 0 missing values for lawrence_park_north
# 0 missing values for lawrence_park_south
# 0 missing values for leaside-bennington
# 0 missing values for little_portugal
# 0 missing values for long_branch
# 0 missing values for malvern
# 0 missing values for maple_leaf
# 0 missing values for markland_wood
# 0 missing values for milliken
# 0 missing values for mimico
# 0 missing values for morningside
# 0 missing values for moss_park
# 0 missing values for mount_dennis
# 0 missing values for mount_olive-silverstone-jamestown
# 0 missing values for mount_pleasant_east
# 0 missing values for mount_pleasant_west
# 0 missing values for new_toronto
# 0 missing values for newtonbrook_east
# 0 missing values for newtonbrook_west
# 0 missing values for niagara
# 0 missing values for north_riverdale
# 0 missing values for north_st_james_town
# 0 missing values for o'connor-parkview
# 0 missing values for oakridge
# 0 missing values for oakwood_village
# 0 missing values for old_east_york
# 0 missing values for palmerston-little_italy
# 0 missing values for parkwoods-donalda
# 0 missing values for pelmo_park-humberlea
# 0 missing values for playter_estates-danforth
# 0 missing values for pleasant_view
# 0 missing values for princess-rosethorn
# 0 missing values for regent_park
# 0 missing values for rexdale-kipling
# 0 missing values for rockcliffe-smythe
# 0 missing values for roncesvalles
# 0 missing values for rosedale-moore_park
# 0 missing values for rouge
# 0 missing values for runnymede-bloor_west_village
# 0 missing values for rustic
# 0 missing values for scarborough_village
# 0 missing values for south_parkdale
# 0 missing values for south_riverdale
# 0 missing values for st_andrew-windfields
# 0 missing values for steeles
# 0 missing values for stonegate-queensway
# 0 missing values for tam_o'shanter-sullivan
# 0 missing values for taylor-massey
# 0 missing values for the_beaches
# 0 missing values for thistletown-beaumond_heights
# 0 missing values for thorncliffe_park
# 0 missing values for trinity-bellwoods
# 0 missing values for university
# 0 missing values for victoria_village
# 0 missing values for waterfront_communities-the_island
# 0 missing values for west_hill
# 0 missing values for west_humber-clairville
# 0 missing values for westminster-branson
# 0 missing values for weston
# 0 missing values for weston-pelham_park
# 0 missing values for wexford/maryvale
# 0 missing values for willowdale_east
# 0 missing values for willowdale_west
# 0 missing values for willowridge-martingrove-richview
# 0 missing values for woburn
# 0 missing values for woodbine_corridor
# 0 missing values for woodbine-lumsden
# 0 missing values for wychwood
# 0 missing values for yonge-eglinton
# 0 missing values for yonge-st_clair
# 0 missing values for york_university_heights
# 0 missing values for yorkdale-glen_park

# %%
# final crime data frame
crime.head()
# Out:
#      category                     topic   characteristic  city_of_toronto  \
# 0  Population  Population and dwellings  population_2019          2731571
# 1       Crime            Crimes by year     assault_2016            18508
# 2       Crime            Crimes by year     assault_2017            18845
# 3       Crime            Crimes by year     assault_2018            19451
# 4       Crime            Crimes by year     assault_2019            20426
#
#   agincourt_north agincourt_south-malvern_west alderwood  annex  \
# 0           29113                        23757     12054  30526
# 1              77                          136        39    257
# 2              71                          115        21    248
# 3              79                          114        30    246
# 4              79                          123        36    288
#
#   banbury-don_mills bathurst_manor  ... willowdale_west  \
# 0             27695          15873  ...           16936
# 1                84             64  ...              97
# 2               109             51  ...              92
# 3                77             58  ...             107
# 4                74             50  ...             112
#
#   willowridge-martingrove-richview woburn woodbine_corridor woodbine-lumsden  \
# 0                            22156  53485             12541             7865
# 1                              102    365                79               33
# 2                              103    400                75               32
# 3                               78    369               101               37
# 4                              101    427                98               30
#
#   wychwood yonge-eglinton yonge-st_clair york_university_heights  \
# 0    14349          11817          12528                   27593
# 1       86             73             39                     361
# 2       55             73             27                     344
# 3       76             78             34                     357
# 4       74            103             37                     370
#
#   yorkdale-glen_park
# 0              14804
# 1                174
# 2                161
# 3                175
# 4                209
#
# [5 rows x 144 columns]

# %%
# save to csv for future use
crime.to_csv('crimes_demo.csv', index = False, header = True)
